# %% [markdown]
# ## Pre-processing

# %%
import pandas as pd

data_life = pd.read_csv('/content/life_expectancy_years.csv')
data_life.head()
# Out:
#        country  1800  1801  1802  1803  1804  1805  1806  1807  1808  ...  \
# 0  Afghanistan  28.2  28.2  28.2  28.2  28.2  28.2  28.1  28.1  28.1  ...
# 1      Albania  35.4  35.4  35.4  35.4  35.4  35.4  35.4  35.4  35.4  ...
# 2      Algeria  28.8  28.8  28.8  28.8  28.8  28.8  28.8  28.8  28.8  ...
# 3      Andorra   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4       Angola  27.0  27.0  27.0  27.0  27.0  27.0  27.0  27.0  27.0  ...
#
#    2091  2092  2093  2094  2095  2096  2097  2098  2099  2100
# 0  76.5  76.6  76.7  76.9  77.0  77.1  77.3  77.4  77.5  77.7
# 1  87.4  87.5  87.6  87.7  87.8  87.9  88.0  88.1  88.2  88.3
# 2  88.3  88.4  88.5  88.6  88.7  88.8  88.9  89.0  89.1  89.2
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  78.7  78.9  79.0  79.1  79.3  79.4  79.5  79.7  79.8  79.9
#
# [5 rows x 302 columns]

# %%
data_life.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Columns: 302 entries, country to 2100
# dtypes: float64(301), object(1)
# memory usage: 441.3+ KB

# %%
data_life.describe()
# Out:
#              1800        1801        1802        1803        1804        1805  \
# count  184.000000  184.000000  184.000000  184.000000  184.000000  184.000000
# mean    31.502717   31.461957   31.478804   31.383152   31.459239   31.586413
# std      3.814689    3.806303    3.938674    3.962376    3.934674    4.010884
# min     23.400000   23.400000   23.400000   19.600000   23.400000   23.400000
# 25%     29.075000   28.975000   28.900000   28.900000   28.975000   29.075000
# 50%     31.750000   31.650000   31.550000   31.500000   31.550000   31.650000
# 75%     33.825000   33.900000   33.825000   33.625000   33.725000   33.825000
# max     42.900000   40.300000   44.400000   44.800000   42.800000   44.300000
#
#              1806        1807        1808        1809  ...        2091  \
# count  184.000000  184.000000  184.000000  184.000000  ...  184.000000
# mean    31.644565   31.598370   31.383152   31.310326  ...   83.758152
# std      4.110598    3.981247    4.087872    4.040580  ...    5.600794
# min     23.400000   23.400000   12.500000   13.400000  ...   67.100000
# 25%     29.075000   29.075000   28.975000   28.875000  ...   79.500000
# 50%     31.750000   31.750000   31.550000   31.500000  ...   84.200000
# 75%     33.925000   33.925000   33.725000   33.625000  ...   88.125000
# max     45.800000   43.600000   43.500000   41.700000  ...   93.700000
#
#             2092        2093        2094        2095        2096        2097  \
# count  184.00000  184.000000  184.000000  184.000000  184.000000  184.000000
# mean    83.87663   83.996196   84.119022   84.236957   84.358152   84.478804
# std      5.59444    5.589074    5.577601    5.570850    5.566060    5.556903
# min     67.30000   67.400000   67.500000   67.600000   67.700000   67.800000
# 25%     79.70000   79.800000   79.900000   80.075000   80.200000   80.375000
# 50%     84.35000   84.450000   84.550000   84.650000   84.750000   84.850000
# 75%     88.22500   88.325000   88.500000   88.600000   88.700000   88.800000
# max     93.90000   94.000000   94.100000   94.200000   94.300000   94.400000
#
#              2098       2099        2100
# count  184.000000  184.00000  184.000000
# mean    84.593478   84.71087   84.829891
# std      5.550234    5.54055    5.532609
# min     67.900000   68.00000   68.100000
# 25%     80.475000   80.57500   80.775000
# 50%     85.000000   85.15000   85.250000
# 75%     88.900000   89.00000   89.100000
# max     94.500000   94.70000   94.800000
#
# [8 rows x 301 columns]

# %% [markdown]
# Jika ingin mencari suatu negara di dalam data, maka bisa melakukan code seperti dibawah

# %%
Canada = data_life['country'] == 'Canada'
data_life[Canada]
# Out:
#    country  1800  1801  1802  1803  1804  1805  1806  1807  1808  ...  2091  \
# 30  Canada  39.0  39.0  39.0  39.0  39.0  39.0  39.0  39.0  39.0  ...  90.6
#
#     2092  2093  2094  2095  2096  2097  2098  2099  2100
# 30  90.7  90.8  90.9  91.0  91.2  91.3  91.4  91.5  91.6
#
# [1 rows x 302 columns]

# %% [markdown]
# Membuat variabel baru yang berisi data-data pada negara Canada.
#
# data_life.iloc[30][1:].values
#
# .iloc[30] digunakan untuk mencari baris ke 30 pada data
#
# [1:] digunakan untuk memberi range data dari kolom pertama hingga terakhir
#
# .values digunakan untuk menginput hanya value atau isi dari kolom yang sudah beri range

# %%
Can_life_expectancy = data_life.iloc[30][1:].values
print(Can_life_expectancy)
# Out:
# [39.0 39.0 39.0 39.0 39.0 39.0 39.0 39.0 39.0 39.0 39.0 39.0 39.0 39.0
#  39.0 39.0 39.0 39.0 39.0 39.0 39.0 39.0 39.0 39.0 39.0 39.0 39.0 39.0
#  39.0 39.0 39.0 39.0 39.2 39.3 39.4 39.5 39.7 39.8 39.9 40.1 40.2 40.3
#  40.4 40.5 40.5 40.6 40.7 40.8 40.8 40.9 41.0 41.1 41.1 41.2 41.2 41.3
#  41.3 41.4 41.4 41.5 41.5 41.6 41.7 41.8 41.9 42.0 42.1 42.2 42.3 42.4
#  42.5 42.6 42.8 43.0 43.2 43.4 43.6 43.9 44.1 44.3 44.5 44.7 44.8 44.8
#  44.9 44.9 45.0 45.0 45.0 45.1 45.1 45.2 45.5 45.9 46.2 46.6 46.9 47.3
#  47.6 47.9 48.3 48.6 49.0 49.4 49.8 50.2 50.6 51.0 51.4 51.7 52.1 52.5
#  53.0 53.4 53.9 54.3 54.8 55.2 47.2 56.1 56.6 57.0 57.0 57.0 58.8 59.3
#  58.0 58.7 58.6 58.0 59.0 60.4 61.4 62.4 62.8 62.5 62.7 61.4 63.3 63.7
#  64.0 63.8 64.7 64.6 65.3 66.3 66.5 66.8 67.3 67.7 68.3 68.5 68.8 69.1
#  70.0 70.0 70.0 70.0 70.6 70.7 71.0 71.3 71.3 71.3 71.7 71.8 71.9 72.1
#  72.3 72.5 72.7 72.8 72.9 73.1 73.3 73.6 73.9 74.2 74.5 74.9 75.2 75.5
#  75.8 76.0 76.3 76.4 76.6 76.7 76.9 77.1 77.3 77.6 77.7 77.7 77.9 78.0
#  78.2 78.5 78.7 78.9 79.2 79.5 79.6 79.8 80.1 80.2 80.6 80.7 80.8 81.1
#  81.4 81.7 81.7 81.9 81.8 81.7 81.9 82.0 82.1 82.2 82.3 82.5 82.6 82.8
#  82.9 83.1 83.2 83.4 83.5 83.7 83.8 84.0 84.1 84.2 84.3 84.5 84.6 84.7
#  84.8 85.0 85.1 85.2 85.3 85.4 85.5 85.7 85.8 85.9 86.0 86.1 86.2 86.3
#  86.4 86.5 86.7 86.8 86.9 87.0 87.1 87.2 87.3 87.4 87.5 87.6 87.7 87.8
#  88.0 88.1 88.2 88.3 88.4 88.5 88.6 88.7 88.8 88.9 89.0 89.1 89.2 89.3
#  89.5 89.6 89.7 89.8 89.9 90.0 90.1 90.2 90.3 90.4 90.5 90.6 90.7 90.8
#  90.9 91.0 91.2 91.3 91.4 91.5 91.6]

# %% [markdown]
# Membuat array baru untuk tahun berdasarkan kolom tahun di data life expectancy

# %%
import numpy as np

tahun = np.array(range(int(data_life.columns[1:].min()), int(data_life.columns[1:].max()) + 1))

print(tahun)
# Out:
# [1800 1801 1802 1803 1804 1805 1806 1807 1808 1809 1810 1811 1812 1813
#  1814 1815 1816 1817 1818 1819 1820 1821 1822 1823 1824 1825 1826 1827
#  1828 1829 1830 1831 1832 1833 1834 1835 1836 1837 1838 1839 1840 1841
#  1842 1843 1844 1845 1846 1847 1848 1849 1850 1851 1852 1853 1854 1855
#  1856 1857 1858 1859 1860 1861 1862 1863 1864 1865 1866 1867 1868 1869
#  1870 1871 1872 1873 1874 1875 1876 1877 1878 1879 1880 1881 1882 1883
#  1884 1885 1886 1887 1888 1889 1890 1891 1892 1893 1894 1895 1896 1897
#  1898 1899 1900 1901 1902 1903 1904 1905 1906 1907 1908 1909 1910 1911
#  1912 1913 1914 1915 1916 1917 1918 1919 1920 1921 1922 1923 1924 1925
#  1926 1927 1928 1929 1930 1931 1932 1933 1934 1935 1936 1937 1938 1939
#  1940 1941 1942 1943 1944 1945 1946 1947 1948 1949 1950 1951 1952 1953
#  1954 1955 1956 1957 1958 1959 1960 1961 1962 1963 1964 1965 1966 1967
#  1968 1969 1970 1971 1972 1973 1974 1975 1976 1977 1978 1979 1980 1981
#  1982 1983 1984 1985 1986 1987 1988 1989 1990 1991 1992 1993 1994 1995
#  1996 1997 1998 1999 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009
#  2010 2011 2012 2013 2014 2015 2016 2017 2018 2019 2020 2021 2022 2023
#  2024 2025 2026 2027 2028 2029 2030 2031 2032 2033 2034 2035 2036 2037
#  2038 2039 2040 2041 2042 2043 2044 2045 2046 2047 2048 2049 2050 2051
#  2052 2053 2054 2055 2056 2057 2058 2059 2060 2061 2062 2063 2064 2065
#  2066 2067 2068 2069 2070 2071 2072 2073 2074 2075 2076 2077 2078 2079
#  2080 2081 2082 2083 2084 2085 2086 2087 2088 2089 2090 2091 2092 2093
#  2094 2095 2096 2097 2098 2099 2100]

# %%
import matplotlib.pyplot as plt

plt.plot(tahun, Can_life_expectancy, 'r*')
plt.show()

# %% [markdown]
# Berdasarkan plot diatas, terjadi peningkatan umur dinegara Canada setiap tahunnya

# %%
Indonesia = data_life['country'] == 'Indonesia'
data_life[Indonesia]
# Out:
#       country  1800  1801  1802  1803  1804  1805  1806  1807  1808  ...  \
# 77  Indonesia  30.0  30.0  30.0  30.0  30.0  30.0  30.0  30.0  30.0  ...
#
#     2091  2092  2093  2094  2095  2096  2097  2098  2099  2100
# 77  83.0  83.2  83.3  83.5  83.6  83.7  83.9  84.0  84.1  84.3
#
# [1 rows x 302 columns]

# %%
Idn_life_expectancy = data_life.iloc[77][1:].values
print(Idn_life_expectancy)
# Out:
# [30.0 30.0 30.0 30.0 30.0 30.0 30.0 30.0 30.0 30.0 30.0 30.0 30.0 30.0
#  30.0 30.0 30.0 30.0 30.0 30.0 30.0 30.0 30.0 30.0 30.0 30.0 30.0 30.0
#  30.0 30.0 30.0 30.0 30.0 30.0 30.0 30.0 30.0 30.0 30.0 30.0 30.0 30.0
#  30.0 30.0 30.0 30.0 30.0 30.0 30.0 30.0 30.0 30.0 30.0 30.0 30.0 30.0
#  30.0 30.0 30.0 30.0 30.0 30.0 30.0 30.0 30.0 30.0 30.0 30.0 30.0 30.0
#  30.0 30.0 30.0 30.0 30.0 30.1 30.1 30.1 30.1 30.1 30.1 30.1 30.1 30.1
#  30.1 30.1 30.1 30.2 30.2 30.2 30.2 30.2 30.2 30.2 30.2 30.2 30.2 30.3
#  30.3 30.3 30.3 30.3 30.3 30.3 30.3 30.3 30.3 30.3 30.4 30.4 30.4 30.4
#  30.4 30.4 30.4 30.4 30.4 30.4 14.2 30.4 30.5 30.5 30.5 30.5 30.5 30.5
#  30.5 30.5 31.0 31.6 32.1 32.6 33.1 33.6 34.1 34.7 35.2 35.7 36.1 36.5
#  36.9 37.3 29.6 28.6 27.6 26.6 31.2 31.7 32.3 32.8 37.3 37.8 38.8 39.7
#  40.6 41.6 42.5 43.4 44.3 45.2 46.0 46.9 47.7 48.5 49.4 44.8 45.2 51.7
#  52.5 53.3 54.0 54.5 55.0 55.6 56.3 56.7 57.2 57.8 58.3 58.9 59.5 60.2
#  60.7 61.1 61.6 62.0 62.4 62.6 63.1 63.5 63.9 64.3 64.8 65.2 65.6 66.0
#  66.4 66.7 66.9 67.0 67.3 67.6 67.8 68.0 66.5 68.5 68.7 69.0 69.2 69.4
#  69.7 70.0 70.3 70.5 70.8 71.0 71.2 71.5 71.7 71.9 72.1 72.3 72.5 72.6
#  72.8 73.0 73.1 73.3 73.5 73.7 73.8 74.0 74.2 74.3 74.5 74.7 74.8 75.0
#  75.1 75.3 75.5 75.6 75.8 75.9 76.1 76.2 76.4 76.5 76.7 76.8 77.0 77.1
#  77.3 77.4 77.6 77.7 77.9 78.0 78.2 78.3 78.5 78.6 78.8 79.0 79.1 79.3
#  79.4 79.5 79.7 79.8 80.0 80.1 80.3 80.4 80.6 80.7 80.9 81.0 81.2 81.3
#  81.5 81.6 81.8 81.9 82.1 82.2 82.3 82.5 82.6 82.8 82.9 83.0 83.2 83.3
#  83.5 83.6 83.7 83.9 84.0 84.1 84.3]

# %%
tahunId = np.array(range(int(data_life.columns[1:].min()), int(data_life.columns[1:].max()) + 1))
print(tahunId)
# Out:
# [1800 1801 1802 1803 1804 1805 1806 1807 1808 1809 1810 1811 1812 1813
#  1814 1815 1816 1817 1818 1819 1820 1821 1822 1823 1824 1825 1826 1827
#  1828 1829 1830 1831 1832 1833 1834 1835 1836 1837 1838 1839 1840 1841
#  1842 1843 1844 1845 1846 1847 1848 1849 1850 1851 1852 1853 1854 1855
#  1856 1857 1858 1859 1860 1861 1862 1863 1864 1865 1866 1867 1868 1869
#  1870 1871 1872 1873 1874 1875 1876 1877 1878 1879 1880 1881 1882 1883
#  1884 1885 1886 1887 1888 1889 1890 1891 1892 1893 1894 1895 1896 1897
#  1898 1899 1900 1901 1902 1903 1904 1905 1906 1907 1908 1909 1910 1911
#  1912 1913 1914 1915 1916 1917 1918 1919 1920 1921 1922 1923 1924 1925
#  1926 1927 1928 1929 1930 1931 1932 1933 1934 1935 1936 1937 1938 1939
#  1940 1941 1942 1943 1944 1945 1946 1947 1948 1949 1950 1951 1952 1953
#  1954 1955 1956 1957 1958 1959 1960 1961 1962 1963 1964 1965 1966 1967
#  1968 1969 1970 1971 1972 1973 1974 1975 1976 1977 1978 1979 1980 1981
#  1982 1983 1984 1985 1986 1987 1988 1989 1990 1991 1992 1993 1994 1995
#  1996 1997 1998 1999 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009
#  2010 2011 2012 2013 2014 2015 2016 2017 2018 2019 2020 2021 2022 2023
#  2024 2025 2026 2027 2028 2029 2030 2031 2032 2033 2034 2035 2036 2037
#  2038 2039 2040 2041 2042 2043 2044 2045 2046 2047 2048 2049 2050 2051
#  2052 2053 2054 2055 2056 2057 2058 2059 2060 2061 2062 2063 2064 2065
#  2066 2067 2068 2069 2070 2071 2072 2073 2074 2075 2076 2077 2078 2079
#  2080 2081 2082 2083 2084 2085 2086 2087 2088 2089 2090 2091 2092 2093
#  2094 2095 2096 2097 2098 2099 2100]

# %%
plt.plot(tahunId, Idn_life_expectancy, 'r*')
plt.show()

# %% [markdown]
# ## Training and Test Model
# Pada bagian ini, digunakan untuk melakukan prediksi umur berdasarkan data-data yang sudah ada

# %% [markdown]
# sklearn dapat digunakan untuk melakukan prediksi dengan cara membagi data menjadi 2 yaitu untuk training dan untuk testing

# %% [markdown]
# Yang pertama dilakukan yaitu membuat data frame baru untuk negara Canada

# %%
from sklearn.model_selection import train_test_split

df_can = pd.DataFrame()
df_can['Tahun'] = tahun
df_can['Life Expectancy'] = Can_life_expectancy
df_can.head()
# Out:
#    Tahun Life Expectancy
# 0   1800            39.0
# 1   1801            39.0
# 2   1802            39.0
# 3   1803            39.0
# 4   1804            39.0

# %% [markdown]
# Membagi data yang sebelumnya dibuat menjadi data training dan testing.
#
# Biasanya data testing sebesar 0.3 dari data yang ada

# %%
X = df_can[['Tahun']] #feature
y = df_can['Life Expectancy'] # target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 50)
# X_train feature training
# X_test feature test
# y_train target training
# y_train feature test

# %% [markdown]
# print shape dari masing-masing data untuk melihat total data x dan y bagian training maupun testing. Total data x ditraining harus memiliki nilai yang sama dengan y training, begitu juga dengan test. sehingga tidak ada data yang tidak seimbang

# %%
print('Original Data Feature : ', X.shape)
print('Original Target Data : ', y.shape)

print('Training Data Feature : ', X_train.shape)
print('Target Data (Training) : ', y_train.shape)

print('Testing Data Feature : ', X_test.shape)
print('Target Data (Testing) : ', y_test.shape)
# Out:
# Original Data Feature :  (301, 1)
# Original Target Data :  (301,)
# Training Data Feature :  (210, 1)
# Target Data (Training) :  (210,)
# Testing Data Feature :  (91, 1)
# Target Data (Testing) :  (91,)

# %%
X_train.head()
# Out:
#      Tahun
# 140   1940
# 135   1935
# 89    1889
# 144   1944
# 206   2006

# %%
y_train.head()
# Out:
# 140    64.0
# 135    62.5
# 89     45.1
# 144    65.3
# 206    80.6
# Name: Life Expectancy, dtype: object

# %%
X_test.head()
# Out:
#      Tahun
# 239   2039
# 97    1897
# 203   2003
# 220   2020
# 102   1902

# %%
y_test.head()
# Out:
# 239    85.0
# 97     47.3
# 203    79.8
# 220    82.3
# 102    49.0
# Name: Life Expectancy, dtype: object

# %%
df_Id = pd.DataFrame()
df_Id['Tahun'] = tahunId
df_Id['Life Expectancy'] = Idn_life_expectancy
df_Id.head()
# Out:
#    Tahun Life Expectancy
# 0   1800            30.0
# 1   1801            30.0
# 2   1802            30.0
# 3   1803            30.0
# 4   1804            30.0

# %%
XId = df_Id[['Tahun']] #feature
yId = df_Id['Life Expectancy'] # target

X_trainId, X_testId, y_trainId, y_testId = train_test_split(X, y, test_size = 0.3, random_state = 50)
# X_train feature training
# X_test feature test
# y_train target training
# y_train feature test

# %%
print('Original Data Feature : ', XId.shape)
print('Original Target Data : ', yId.shape)

print('Training Data Feature : ', X_trainId.shape)
print('Target Data (Training) : ', y_trainId.shape)

print('Testing Data Feature : ', X_testId.shape)
print('Target Data (Testing) : ', y_testId.shape)
# Out:
# Original Data Feature :  (301, 1)
# Original Target Data :  (301,)
# Training Data Feature :  (210, 1)
# Target Data (Training) :  (210,)
# Testing Data Feature :  (91, 1)
# Target Data (Testing) :  (91,)

# %%
X_trainId.head()
# Out:
#      Tahun
# 140   1940
# 135   1935
# 89    1889
# 144   1944
# 206   2006

# %%
y_trainId.head()
# Out:
# 140    36.9
# 135    34.7
# 89     30.2
# 144    27.6
# 206    68.7
# Name: Life Expectancy, dtype: object

# %%
X_testId.head()
# Out:
#      Tahun
# 239   2039
# 97    1897
# 203   2003
# 220   2020
# 102   1902

# %%
y_testId.head()
# Out:
# 239    75.3
# 97     30.3
# 203    68.0
# 220    72.1
# 102    30.3
# Name: Life Expectancy, dtype: object

# %% [markdown]
# ## Modeling

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.coef_, model.intercept_
# Out:
# (array([0.21548323]), -355.6492453720257)

# %%
prediksi = model.predict(X_test)
prediksi
# Out:
# array([83.72105115, 53.12243314, 75.96365503, 79.62686986, 54.19984927,
#        61.52627893, 49.89018476, 73.37785633, 39.54698995, 50.10566799,
#        47.95083573, 70.36109117, 92.98682984, 67.99077569, 66.69787634,
#        68.20625892, 53.55339959, 67.12884279, 83.93653437, 53.33791637,
#        42.5637551 , 40.62440607, 35.66829189, 37.39215769, 72.51592343,
#        64.32756086, 45.79600348, 84.1520176 , 82.85911824, 48.16631896,
#        58.724997  , 49.67470154, 40.19343962, 36.53022479, 45.36503703,
#        50.53663444, 85.66040017, 94.92617886, 92.55586339, 73.80882278,
#        68.42174214, 33.94442609, 76.39462148, 34.37539254, 37.60764092,
#        86.52233307, 48.59728541, 76.17913826, 85.22943372, 66.05142667,
#        54.4153325 , 38.90054027, 36.09925834, 92.77134661, 35.45280866,
#        58.29403055, 46.44245316, 70.5765744 , 78.98042019, 82.64363502,
#        79.41138664, 89.10813178, 57.8630641 , 94.27972919, 84.36750082,
#        39.33150672, 51.18308412, 93.20231306, 58.50951378, 72.08495698,
#        86.30684985, 42.13278865, 55.2772654 , 32.86700996, 81.13525244,
#        80.91976922, 32.43604351, 77.25655438, 47.08890283, 56.78564797,
#        69.28367505, 46.65793638, 89.97006468, 40.40892285, 86.95329953,
#        37.17667447, 57.0011312 , 53.76888282, 55.49274862, 94.71069564,
#        64.11207764])

# %%
y_test
# Out:
# 239    85.0
# 97     47.3
# 203    79.8
# 220    82.3
# 102    49.0
#        ...
# 115    54.3
# 100    48.3
# 108    51.4
# 290    90.5
# 148    67.3
# Name: Life Expectancy, Length: 91, dtype: object

# %%
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test, prediksi)
print('Nilai MSE: ', mse)

rmse = mean_squared_error(y_test, prediksi, squared = False)
print('Nilai RMSE: ', rmse)
# Out:
# Nilai MSE:  12.867940270251633
# Nilai RMSE:  3.587191139352855

# %%
modelId = LinearRegression()

modelId.fit(X_trainId, y_trainId)

modelId.coef_, modelId.intercept_
# Out:
# (array([0.23149966]), -401.72136115433335)

# %%
prediksiId = modelId.predict(X_testId)
prediksiId
# Out:
# array([70.30644738, 37.43349554, 61.97245959, 65.90795382, 38.59099384,
#        46.46198231, 33.96100062, 59.19446366, 22.8490169 , 34.19250028,
#        31.87750368, 55.95346841, 80.2609328 , 53.40697214, 52.01797417,
#        53.6384718 , 37.89649486, 52.48097349, 70.53794704, 37.6649952 ,
#        26.09001215, 24.00651521, 18.68202301, 20.53402029, 58.26846502,
#        49.4714779 , 29.56250707, 70.7694467 , 69.38044874, 32.10900334,
#        43.45248672, 33.72950096, 23.54351588, 19.60802165, 29.09950774,
#        34.65549961, 72.38994433, 82.34442975, 79.79793348, 59.65746298,
#        53.86997146, 16.83002572, 62.43545891, 17.29302504, 20.76551995,
#        73.31594297, 32.57200266, 62.20395925, 71.92694501, 51.32347519,
#        38.8224935 , 22.15451792, 19.14502233, 80.02943314, 18.45052334,
#        42.9894874 , 30.25700605, 56.18496807, 65.21345484, 69.14894908,
#        65.67645416, 76.0939389 , 42.52648808, 81.64993076, 71.00094636,
#        22.61751724, 35.34999859, 80.49243246, 43.22098706, 57.80546569,
#        73.08444331, 25.62701283, 39.74849215, 15.67252741, 67.52845145,
#        67.29695179, 15.20952809, 63.36145756, 30.95150503, 41.36898977,
#        54.7959701 , 30.48850571, 77.01993755, 23.77501554, 73.77894229,
#        20.30252063, 41.60048943, 38.12799452, 39.97999181, 82.11293009,
#        49.23997824])

# %%
y_testId
# Out:
# 239    75.3
# 97     30.3
# 203    68.0
# 220    72.1
# 102    30.3
#        ...
# 115    30.4
# 100    30.3
# 108    30.4
# 290    82.9
# 148    32.3
# Name: Life Expectancy, Length: 91, dtype: object

# %%
mseID = mean_squared_error(y_testId, prediksiId)
print('Nilai MSE : ', mseID)

rmseId = mean_squared_error(y_testId, prediksiId, squared = False)
print('Nilai RMSE : ', rmseId)
# Out:
# Nilai MSE :  54.19400915173682
# Nilai RMSE :  7.3616580436567975

# %% [markdown]
# ## Visualisasi

# %%
x_line = [[df_can['Tahun'].min()], [df_can['Tahun'].max()]]
y_line = model.predict(x_line)

plt.plot(df_can['Tahun'], df_can['Life Expectancy'], 'r*')
plt.plot(x_line, y_line, 'g-')
plt.show
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x_lineId = [[df_Id['Tahun'].min()], [df_Id['Tahun'].max()]]
y_lineId = modelId.predict(x_lineId)


plt.plot(df_Id['Tahun'], df_Id['Life Expectancy'], 'r*')
plt.plot(x_lineId, y_lineId, 'g-')
plt.show
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Sum of Squares

# %%
ss_resCan = ((y_test - prediksi) ** 2).sum(axis = 0)
ss_resCan
# Out:
# 1170.9825645928995

# %%
ss_resId = ((y_testId - prediksiId) ** 2).sum(axis = 0)
ss_resId
# Out:
# 4931.654832808049

# %% [markdown]
# ## Total Sum of Squares

# %%
y_mean = np.average(y_test, axis = 0)

# %%
SST_Can = ((y_test - y_mean)**2).sum(axis = 0)
SST_Can
# Out:
# 34178.33604395605

# %%
y_meanId = np.average(y_testId, axis = 0)
y_meanId
# Out:
# 48.38241758241758

# %%
SST_Id = ((y_testId - y_meanId) ** 2).sum(axis = 0)
SST_Id
# Out:
# 40023.571868131854

# %% [markdown]
# ## R Squared
#
# Setelah mengihtung Sum of Squared dan Total Sum of Squared, dilanjutkan dengan menghitung nilai dari R squared atau koefisien determinasi
#
#  Nilai R Squared yang baik adalah nilai yang mendekati 1

# %%
#R2 = 1 - (SSR/SST)

RCan = 1 - (ss_resCan / SST_Can)
RCan
# Out:
# 0.96573904115499

# %%
#Atau dengan import library dari sklearn
from sklearn.metrics import r2_score

print(r2_score(y_test, prediksi))
# Out:
# 0.96573904115499

# %% [markdown]
# Berdasarkan hasil perhitungan R2 score diatas, menunjukkan model prediksi life expectancy di Canada memiliki tingkat akurasi sangat tinggi. Akurasi tinggi tersebut ditunjukkan dengan nilai R2 sebesar 0.9656.

# %%
RId = 1 - (ss_resId / SST_Id)
RId
# Out:
# 0.8767812415879153

# %%
print(r2_score(y_testId, prediksiId))
# Out:
# 0.8767812415879153

# %% [markdown]
# Berdasarkan hasil perhitungan R2 score diatas, menunjukkan model prediksi life expectancy di Indonesia memiliki tingkat akurasi yang baik dengan nilai R2 sebesar 0.8767.
